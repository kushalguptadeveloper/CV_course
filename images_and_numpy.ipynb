# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open("/Users/kushalgupta/downloads/i.jpg")

# %%
pic_red = pic.copy()
pic_array = np.asarray(pic_red)

# %%
pic_array.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(pic_array)

# %%
plt.imshow(pic_array[:,:,0],cmap = 'gray')

# %%
plt.imshow(pic_array[:,:,1],cmap = 'gray')

# %%
plt.imshow(pic_array[:,:,2],cmap = 'gray')

# %%
pic_array.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
pic_array.setflags(write=1)

# %%
pic_array[:,:,1] = 0
pic_array[:,:,2] = 0

# %%
plt.imshow(pic_array)
